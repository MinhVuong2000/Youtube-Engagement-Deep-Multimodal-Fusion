# %% [markdown]
# # Define functions for crawler video

# %% [markdown]
# ## Crawl video and audio

# %%
import os
import yt_dlp
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip, ffmpeg_extract_audio

output_dir = "data"
os.makedirs(output_dir, exist_ok=True)

def crawler_video(video_id, year):
    try:
        video_url = "https://youtu.be/" + video_id
        # Tải xuống 1 phút đầu video + audio
        temp_video_path = os.path.join(output_dir+"/video/" + str(year) + "/tmp_" + str(video_id) + ".mp4")
        video_path = os.path.join(output_dir+"/video/" + str(year) + "/" + str(video_id) + ".mp4")
        download_opts = {
            "format": "mp4",
            "outtmpl": temp_video_path,
            "external_downloader": "ffmpeg",
            "external_downloader_args": [f"-ss 0 -i {temp_video_path} -t 60 -c copy {video_path}"]
        }
        with yt_dlp.YoutubeDL(download_opts) as ydl:
            ydl.download([video_url])
        
        ffmpeg_extract_subclip(temp_video_path, 0, 60, outputfile=video_path)
        # os.system(f"ffmpeg -ss 0 -i {temp_video_path} -t 60 -c copy {video_path}")
        os.remove(temp_video_path)

        # Tách audio ra khỏi video
        audio_path = os.path.join(output_dir+"/audio/" + str(year) + "/" + str(video_id) + ".mp3")
        
        ffmpeg_extract_audio(video_path, audio_path)
        
        return True
    except Exception as e:
        print("❌ Không thể tải video")
        print(e)
        return False

# %% [markdown]
# ## Crawl thumbnail

# %%
def crawler_thumbnail(video_id, year):
    video_url = "https://youtu.be/" + video_id
    try:
        # Tạo thư mục thumbnail nếu chưa có
        save_dir = os.path.join(output_dir, "thumbnail", year)
        os.makedirs(save_dir, exist_ok=True)

        # Cấu hình yt-dlp để thu thập thông tin video
        ydl_opts = {
            "quiet": True,
            "extract_flat": False,
            "nocheckcertificate": True,
            "format": "bestaudio/best",
            "postprocessors": [
                {"key": "FFmpegExtractAudio", "preferredcodec": "mp3", "preferredquality": "192"},
            ],
            "outtmpl": {"default": os.path.join(output_dir, "%(id)s.%(ext)s")},
            "writethumbnail": True,  # Chỉ viết metadata thumbnail, không tải
            "skip_download": True,   # Không tải audio/video
        }

        # Thu thập thông tin video
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(video_url, download=False)

        # ID video thực tế
        video_id = info["id"]

        # Lọc danh sách thumbnail
        thumbnail_urls = sorted(
            [thumb for thumb in info.get("thumbnails", []) if "height" in thumb],
            key=lambda x: x["height"], reverse=True
        )[:3]

        # Nếu không có height, lấy 3 ảnh đầu tiên
        if not thumbnail_urls:
            thumbnail_urls = info.get("thumbnails", [])[:3]

        # Tải xuống các thumbnail
        for i, thumb in enumerate(thumbnail_urls):
            thumb_url = thumb["url"]
            response = requests.get(thumb_url, stream=True)
            if response.status_code == 200:
                file_path = os.path.join(save_dir, f"{video_id}_thumb{i+1}.jpg")
                with open(file_path, "wb") as file:
                    file.write(response.content)
                print(f"✅ Đã tải {file_path}")
            else:
                print(f"❌ Không thể tải {thumb_url}")

    except Exception as e:
        print(f"❌ Lỗi: {e}")

# %% [markdown]
# ## Crawl title & tag

# %%
def get_video_info(video_id):
    video_url = f"https://youtu.be/{video_id}"
    ydl_opts = {
        'quiet': True,
        'no_warnings': True,
        'extract_flat': True,
        'skip_download': True,
    }
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(video_url, download=False)
        
    title = info.get('title', '')
    tags = info.get('tags', [])[:5]  # Get top 5 tags
    
    return title, tags

# %% [markdown]
# # Crawling

# %%
category = "test"

# %%
import pandas as pd
from enum import Enum

class CrawlStatus(Enum):
    NOT_YET="NOT_YET"
    DONE="DONE"

# Load a parquet file
path = f'data/{category}.parquet'
df = pd.read_parquet(path)

if "crawl_status" not in df.columns:
    df["crawl_status"] = CrawlStatus.NOT_YET.value
    print("Created crawl_status")

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df["crawl_status"][i] == CrawlStatus.DONE.value:
        continue
    is_crawl_success = crawler_video(df["id"][i], category)
    if is_crawl_success:
        df.loc[i, "crawl_status"] = CrawlStatus.DONE.value
    if (i % 100 == 10):
        print("Processing {}".format(i))
        df.to_parquet(path)
# Out:
# [youtube] Extracting URL: https://youtu.be/FIkKcpltyfc
# [youtube] FIkKcpltyfc: Downloading webpage
# [youtube] FIkKcpltyfc: Downloading tv client config
# [youtube] FIkKcpltyfc: Downloading player 7d1d50a6
# [youtube] FIkKcpltyfc: Downloading tv player API JSON
# [youtube] FIkKcpltyfc: Downloading ios player API JSON
# [youtube] FIkKcpltyfc: Downloading m3u8 information
# [info] FIkKcpltyfc: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_FIkKcpltyfc.mp4
# [download] 100% of  163.71MiB in 00:00:05 at 31.50MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_FIkKcpltyfc.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/FIkKcpltyfc.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/FIkKcpltyfc.mp4 -ab 3000k -ar 44100 data/audio/test/FIkKcpltyfc.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/nu5DFUZcrs0
# [youtube] nu5DFUZcrs0: Downloading webpage
# [youtube] nu5DFUZcrs0: Downloading tv client config
# [youtube] nu5DFUZcrs0: Downloading player 7d1d50a6
# [youtube] nu5DFUZcrs0: Downloading tv player API JSON
# [youtube] nu5DFUZcrs0: Downloading ios player API JSON
# [youtube] nu5DFUZcrs0: Downloading m3u8 information
# [info] nu5DFUZcrs0: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_nu5DFUZcrs0.mp4
# [download] 100% of   16.91MiB in 00:00:04 at 3.42MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_nu5DFUZcrs0.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/nu5DFUZcrs0.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/nu5DFUZcrs0.mp4 -ab 3000k -ar 44100 data/audio/test/nu5DFUZcrs0.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/z5tRgsYSNjg
# [youtube] z5tRgsYSNjg: Downloading webpage
# [youtube] z5tRgsYSNjg: Downloading tv client config
# [youtube] z5tRgsYSNjg: Downloading player 7d1d50a6
# [youtube] z5tRgsYSNjg: Downloading tv player API JSON
# [youtube] z5tRgsYSNjg: Downloading ios player API JSON
# [youtube] z5tRgsYSNjg: Downloading m3u8 information
# [info] z5tRgsYSNjg: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_z5tRgsYSNjg.mp4
# [download] 100% of  158.79MiB in 00:00:22 at 7.00MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_z5tRgsYSNjg.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/z5tRgsYSNjg.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/z5tRgsYSNjg.mp4 -ab 3000k -ar 44100 data/audio/test/z5tRgsYSNjg.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/UjRJ5_lbhAc
# [youtube] UjRJ5_lbhAc: Downloading webpage
# [youtube] UjRJ5_lbhAc: Downloading tv client config
# [youtube] UjRJ5_lbhAc: Downloading player 7d1d50a6
# [youtube] UjRJ5_lbhAc: Downloading tv player API JSON
# [youtube] UjRJ5_lbhAc: Downloading ios player API JSON
# [youtube] UjRJ5_lbhAc: Downloading m3u8 information
# [info] UjRJ5_lbhAc: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp
Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_EVJx3NrynkQ.mp4
# [download] 100% of   79.42MiB in 00:00:02 at 26.98MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_EVJx3NrynkQ.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/EVJx3NrynkQ.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/EVJx3NrynkQ.mp4 -ab 3000k -ar 44100 data/audio/test/EVJx3NrynkQ.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/JHbzb0Bxl8g
# [youtube] JHbzb0Bxl8g: Downloading webpage
# [youtube] JHbzb0Bxl8g: Downloading tv client config
# [youtube] JHbzb0Bxl8g: Downloading player 7d1d50a6
# [youtube] JHbzb0Bxl8g: Downloading tv player API JSON
# [youtube] JHbzb0Bxl8g: Downloading ios player API JSON
# [youtube] JHbzb0Bxl8g: Downloading m3u8 information
# [info] JHbzb0Bxl8g: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_JHbzb0Bxl8g.mp4
# [download] 100% of   72.95MiB in 00:00:04 at 16.96MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_JHbzb0Bxl8g.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/JHbzb0Bxl8g.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/JHbzb0Bxl8g.mp4 -ab 3000k -ar 44100 data/audio/test/JHbzb0Bxl8g.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/WpBBqVDhSNE
# [youtube] WpBBqVDhSNE: Downloading webpage
# [youtube] WpBBqVDhSNE: Downloading tv client config
# [youtube] WpBBqVDhSNE: Downloading player 7d1d50a6
# [youtube] WpBBqVDhSNE: Downloading tv player API JSON
# [youtube] WpBBqVDhSNE: Downloading ios player API JSON
# [youtube] WpBBqVDhSNE: Downloading m3u8 information
# [info] WpBBqVDhSNE: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_WpBBqVDhSNE.mp4
# [download] 100% of   83.89MiB in 00:00:03 at 24.86MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_WpBBqVDhSNE.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/WpBBqVDhSNE.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/WpBBqVDhSNE.mp4 -ab 3000k -ar 44100 data/audio/test/WpBBqVDhSNE.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/qQ_h3apNhyo
# [youtube] qQ_h3apNhyo: Downloading webpage
# [youtube] qQ_h3apNhyo: Downloading tv client config
# [youtube] qQ_h3apNhyo: Downloading player 7d1d50a6
# [youtube] qQ_h3apNhyo: Downloading tv player API JSON
# [youtube] qQ_h3apNhyo: Downloading ios player API JSON
# [youtube] qQ_h3apNhyo: Downloading m3u8 information
# [info] qQ_h3apNhyo: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_qQ_h3apNhyo.mp4
# [download] 100% of  105.59MiB in 00:00:03 at 26.41MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_qQ_h3apNhyo.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/qQ_h3apNhyo.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/qQ_h3apNhyo.mp4 -ab 3000k -ar 44100 data/audio/test/qQ_h3apNhyo.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/D9w-5LqvJbg
# [youtube] D9w-5LqvJbg: Downloading webpage
# [youtube] D9w-5LqvJbg: Downloading tv client config
# [youtube] D9w-5LqvJbg: Downloading player 7d1d50a6
# [youtube] D9w-5LqvJbg: Downloading tv player API JSON
# [youtube] D9w-5LqvJbg: Downloading ios player API JSON
# [youtube] D9w-5LqvJbg: Downloading m3u8 information
# [info] D9w-5LqvJbg: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_D9w-5LqvJbg.mp4
# [download] 100% of  114.87MiB in 00:00:04 at 27.46MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_D9w-5LqvJbg.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/D9w-5LqvJbg.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/D9w-5LqvJbg.mp4 -ab 3000k -ar 44100 data/audio/test/D9w-5LqvJbg.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/mjADSFkxgRo.mp4 -ab 3000k -ar 44100 data/audio/test/mjADSFkxgRo.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/0bHXirakt0U
# [youtube] 0bHXirakt0U: Downloading webpage
# [youtube] 0bHXirakt0U: Downloading tv client config
# [youtube] 0bHXirakt0U: Downloading player 7d1d50a6
# [youtube] 0bHXirakt0U: Downloading tv player API JSON
# [youtube] 0bHXirakt0U: Downloading ios player API JSON
# [youtube] 0bHXirakt0U: Downloading m3u8 information
# [info] 0bHXirakt0U: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_0bHXirakt0U.mp4
# [download] 100% of   60.59MiB in 00:00:39 at 1.55MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_0bHXirakt0U.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/0bHXirakt0U.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/0bHXirakt0U.mp4 -ab 3000k -ar 44100 data/audio/test/0bHXirakt0U.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/CZf4jDXEOwI
# [youtube] CZf4jDXEOwI: Downloading webpage
# [youtube] CZf4jDXEOwI: Downloading tv client config
# [youtube] CZf4jDXEOwI: Downloading player 7d1d50a6
# [youtube] CZf4jDXEOwI: Downloading tv player API JSON
# [youtube] CZf4jDXEOwI: Downloading ios player API JSON
# [youtube] CZf4jDXEOwI: Downloading m3u8 information
# [info] CZf4jDXEOwI: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_CZf4jDXEOwI.mp4
# [download] 100% of  162.44MiB in 00:00:58 at 2.79MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_CZf4jDXEOwI.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/CZf4jDXEOwI.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/CZf4jDXEOwI.mp4 -ab 3000k -ar 44100 data/audio/test/CZf4jDXEOwI.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/rc_xnYZGAnw
# [youtube] rc_xnYZGAnw: Downloading webpage
# [youtube] rc_xnYZGAnw: Downloading tv client config
# [youtube] rc_xnYZGAnw: Downloading player 82345d49
# [youtube] rc_xnYZGAnw: Downloading tv player API JSON
# [youtube] rc_xnYZGAnw: Downloading ios player API JSON
# [youtube] rc_xnYZGAnw: Downloading m3u8 information
# [info] rc_xnYZGAnw: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_rc_xnYZGAnw.mp4
# [download] 100% of  133.97MiB in 00:01:22 at 1.62MiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_rc_xnYZGAnw.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/rc_xnYZGAnw.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/rc_xnYZGAnw.mp4 -ab 3000k -ar 44100 data/audio/test/rc_xnYZGAnw.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/d2fX-4KE24U
# [youtube] d2fX-4KE24U: Downloading webpage
# [youtube] d2fX-4KE24U: Downloading tv client config
# [youtube] d2fX-4KE24U: Downloading player 7d1d50a6
# [youtube] d2fX-4KE24U: Downloading tv player API JSON
# [youtube] d2fX-4KE24U: Downloading ios player API JSON
# [youtube] d2fX-4KE24U: Downloading m3u8 information
# [info] d2fX-4KE24U: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_d2fX-4KE24U.mp4
# [download] 100% of  141.04MiB in 00:02:30 at 961.65KiB/s
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -ss 0.00 -i data/video/test/tmp_d2fX-4KE24U.mp4 -t 60.00 -map 0 -vcodec copy -acodec copy -copyts data/video/test/d2fX-4KE24U.mp4
# MoviePy - Command successful
# MoviePy - Running:
# >>> /Users/vuongnguyen/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -y -i data/video/test/d2fX-4KE24U.mp4 -ab 3000k -ar 44100 data/audio/test/d2fX-4KE24U.mp3
# MoviePy - Command successful
# [youtube] Extracting URL: https://youtu.be/iuBEoKcEkjo
# [youtube] iuBEoKcEkjo: Downloading webpage
# [youtube] iuBEoKcEkjo: Downloading tv client config
# [youtube] iuBEoKcEkjo: Downloading player 7d1d50a6
# [youtube] iuBEoKcEkjo: Downloading tv player API JSON
# [youtube] iuBEoKcEkjo: Downloading ios player API JSON
# [youtube] iuBEoKcEkjo: Downloading m3u8 information
# [info] iuBEoKcEkjo: Downloading 1 format(s): 18
# [download] Destination: data/video/test/tmp_iuBEoKcEkjo.mp4
# [download]  10.0% of  104.58MiB at    1.69MiB/s ETA 00:55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[96], line 2
#       1 for i in range(len(df)):
# ----> 2     crawler_video(df["id"][i], category)
#       3     if (i % 100 == 10):
#       4         print("Processing {}".format(i))
#
# Cell In[90], line 21, in crawler_video(video_id, year)
#      14 download_opts = {
#      15     "format": "mp4",
#      16     "outtmpl": temp_video_path,
#      17     "external_downloader": "ffmpeg",
#      18     "external_downloader_args": [f"-ss 0 -i {temp_video_path} -t 60 -c copy {video_path}"]
#      19 }
#      20 with yt_dlp.YoutubeDL(download_opts) as ydl:
# ---> 21     ydl.download([video_url])
#      23 ffmpeg_extract_subclip(temp_video_path, 0, 60, outputfile=video_path)
#      24 # os.system(f"ffmpeg -ss 0 -i {temp_video_path} -t 60 -c copy {video_path}")
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3618, in YoutubeDL.download(self, url_list)
#    3615     raise SameFileError(outtmpl)
#    3617 for url in url_list:
# -> 3618     self.__download_wrapper(self.extract_info)(
#    3619         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3621 return self._download_retcode
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3591, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3588 @functools.wraps(func)
#    3589 def wrapper(*args, **kwargs):
#    3590     try:
# -> 3591         res = func(*args, **kwargs)
#    3592     except CookieLoadError:
#    3593         raise
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1626, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1624             raise ExistingVideoReached
#    1625         break
# -> 1626     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1627 else:
#    1628     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1637, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1635 while True:
#    1636     try:
# -> 1637         return func(self, *args, **kwargs)
#    1638     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1639         raise
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1793, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1791 if process:
#    1792     self._wait_for_video(ie_result)
# -> 1793     return self.process_ie_result(ie_result, download, extra_info)
#    1794 else:
#    1795     return ie_result
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1852, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1850 if result_type == 'video':
#    1851     self.add_extra_info(ie_result, extra_info)
# -> 1852     ie_result = self.process_video_result(ie_result, download=download)
#    1853     self._raise_pending_errors(ie_result)
#    1854     additional_urls = (ie_result or {}).get('additional_urls')
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3024, in YoutubeDL.process_video_result(self, info_dict, download)
#    3022 downloaded_formats.append(new_info)
#    3023 try:
# -> 3024     self.process_info(new_info)
#    3025 except MaxDownloadsReached:
#    3026     max_downloads_reached = True
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:177, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     174 @functools.wraps(func)
#     175 def wrapper(self, *args, **kwargs):
#     176     try:
# --> 177         return func(self, *args, **kwargs)
#     178     except _UnsafeExtensionError as error:
#     179         self.report_error(
#     180             f'The extracted extension ({error.extension!r}) is unusual '
#     181             'and will be skipped for safety reasons. '
#     182             f'If you believe this is an error{bug_reports_message(",")}')
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3492, in YoutubeDL.process_info(self, info_dict)
#    3488 dl_filename = existing_video_file(full_filename, temp_filename)
#    3489 if dl_filename is None or dl_filename == temp_filename:
#    3490     # dl_filename == temp_filename could mean that the file was partially downloaded with --no-part.
#    3491     # So we should try to resume the download
# -> 3492     success, real_download = self.dl(temp_filename, info_dict)
#    3493     info_dict['__real_download'] = real_download
#    3494 else:
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3212, in YoutubeDL.dl(self, name, info, subtitle, test)
#    3210 if new_info.get('http_headers') is None:
#    3211     new_info['http_headers'] = self._calc_headers(new_info)
# -> 3212 return fd.download(name, new_info, subtitle)
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/downloader/common.py:464, in FileDownloader.download(self, filename, info_dict, subtitle)
#     461     self.to_screen(f'[download] Sleeping {sleep_interval:.2f} seconds ...')
#     462     time.sleep(sleep_interval)
# --> 464 ret = self.real_download(filename, info_dict)
#     465 self._finish_multiline_status()
#     466 return ret, True
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/downloader/http.py:368, in HttpFD.real_download(self, filename, info_dict)
#     366 try:
#     367     establish_connection()
# --> 368     return download()
#     369 except RetryDownload as err:
#     370     retry.error = err.source_error
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/downloader/http.py:250, in HttpFD.real_download.<locals>.download()
#     247 while True:
#     248     try:
#     249         # Download and write
# --> 250         data_block = ctx.data.read(block_size if not is_test else min(block_size, data_len - byte_counter))
#     251     except TransportError as err:
#     252         retry(err)
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/yt_dlp/networking/_requests.py:143, in RequestsResponseAdapter.read(self, amt)
#     140 def read(self, amt: int | None = None):
#     141     try:
#     142         # Interact with urllib3 response directly.
# --> 143         return self.fp.read(amt, decode_content=True)
#     145     # See urllib3.response.HTTPResponse.read() for exceptions raised on read
#     146     except urllib3.exceptions.SSLError as e:
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File ~/Downloads/Github/Youtube-Engagement-Deep-Multimodal-Fusion/.venv/lib/python3.10/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/homebrew/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/homebrew/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/homebrew/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/homebrew/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_parquet(path)
